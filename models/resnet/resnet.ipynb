# %%
import data_loader
from data_loader import DataFolder
# Out:
# 2781
# 597
# C:\Users\alexg\anaconda3\envs\dsp_project\lib\site-packages\PIL\Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import pandas as pd

plt.ion()   # interactive mode

# %%
from torch.utils.data import DataLoader
from sklearn.model_selection import KFold

def k_fold_train(model,data,optimizer,criterion,scheduler,k_folds=5, num_epochs=25, batch_size=64):  
    # Set fixed random number seed
    torch.manual_seed(42)

    kfold = KFold(n_splits=k_folds, shuffle=True)
    best_result = 0.0
    for fold, (train_ids, test_ids) in enumerate(kfold.split(data)):
        print('---- Fold {}/{} ----'.format(fold+1, k_folds))
        train_subset = []
        for id in train_ids:
            train_subset.append(data.__getitem__(id))
        test_subset = []
        for id in test_ids:
            test_subset.append(data.__getitem__(id))
        train_sampler = data_loader.classes(train_subset)
        test_sampler = data_loader.classes(test_subset)
        #torch.utils.data.SubsetRandomSampler(test_ids)
        
        train_subsampler = data_loader.sampler(train_sampler[0],train_sampler[1],train_sampler[2])
        test_subsampler = data_loader.sampler(test_sampler[0],test_sampler[1],test_sampler[2])

        train_loader = DataLoader(dataset=train_subset, batch_size=batch_size,sampler= train_subsampler)
        test_loader = DataLoader(dataset=test_subset, batch_size=batch_size,sampler = test_subsampler)
    
        dataloaders = {'train': train_loader, 'test': test_loader}
        dataset_sizes = {'train': len(train_subsampler), 'test': len(test_subsampler)}
    
        since = time.time()

        best_model_wts = copy.deepcopy(model.state_dict())
        best_acc = 0.0

        for epoch in range(num_epochs):
            print('Epoch {}/{}'.format(epoch+1, num_epochs))
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'test']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                    phase, epoch_loss, epoch_acc))

                # deep copy the model
                if phase == 'test' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())

            print()

        time_elapsed = time.time() - since
        print('Training complete in {:.0f}m {:.0f}s'.format(
            time_elapsed // 60, time_elapsed % 60))
        print('Best val Acc: {:4f}'.format(best_acc))

        # load best model weights
        model.load_state_dict(best_model_wts)

        if best_acc > best_result:
            best_result=best_acc
            best_model=model
    print('Best val Acc after k-folds: {:4f}'.format(best_result))        
    model_fit=best_model
    return model_fit

# %%
from random_baseline import stats
def test_model(testloader, model):

    model.eval()
    class_names = {'0': 'cctv', '1': 'other'}
    total_labels = []
    total_predicted = []
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            # calculate outputs by running images through the network
            outputs = model(images)
            # the class with the highest energy is what we choose as prediction
            _,predicted = torch.max(outputs.data,1)
            total_labels+=labels.numpy().tolist()
            total_predicted+=predicted.numpy().tolist()
            
    df = pd.DataFrame({'labels':total_labels, 'predictions':total_predicted})
    #df.to_csv('resnet18_10_predictions.csv')

    #Computes the test statistics of the predictions
    for c in np.array([0, 1]):
        accuracy, precision, recall, f1 = stats(df, ['labels', 'predictions'], c)
        print(class_names.get(str(c)) + ' simple accuracy is: ' + str(round(accuracy, 4)))
        print(class_names.get(str(c)) + ' precision is: ' + str(round(precision, 4)))
        print(class_names.get(str(c)) + ' recall is: ' + str(round(recall, 4)))
        print(class_names.get(str(c)) + ' f1 is: ' + str(round(f1, 4)))

# %%
k_folds = 5
num_epochs = 25
batch_size = 64

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = models.resnet18(pretrained=True)
num_ftrs = model.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model.fc = nn.Linear(num_ftrs, 2)

model = model.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
data = data_loader.train_dataset
print(data)
# Out:
# <data_loader.DataFolder object at 0x000001BA97590190>

# %%
model_fit = k_fold_train(model,data,optimizer,criterion,scheduler,k_folds,num_epochs,batch_size)
# Out:
# ---- Fold 1/5 ----
# Epoch 1/25
# ----------
# train Loss: 0.3984 Acc: 0.8138
# test Loss: 0.2147 Acc: 0.9138
#
# Epoch 2/25
# ----------
# train Loss: 0.1451 Acc: 0.9505
# test Loss: 0.1343 Acc: 0.9461
#
# Epoch 3/25
# ----------
# train Loss: 0.0779 Acc: 0.9780
# test Loss: 0.1711 Acc: 0.9336
#
# Epoch 4/25
# ----------
# train Loss: 0.0526 Acc: 0.9829
# test Loss: 0.1627 Acc: 0.9318
#
# Epoch 5/25
# ----------
# train Loss: 0.0386 Acc: 0.9906
# test Loss: 0.2360 Acc: 0.9156
#
# Epoch 6/25
# ----------
# train Loss: 0.0262 Acc: 0.9933
# test Loss: 0.1649 Acc: 0.9210
#
# Epoch 7/25
# ----------
# train Loss: 0.0217 Acc: 0.9978
# test Loss: 0.2634 Acc: 0.9066
#
# Epoch 8/25
# ----------
# train Loss: 0.0241 Acc: 0.9964
# test Loss: 0.1884 Acc: 0.9138
#
# Epoch 9/25
# ----------
# train Loss: 0.0187 Acc: 0.9964
# test Loss: 0.1861 Acc: 0.9372
#
# Epoch 10/25
# ----------
# train Loss: 0.0184 Acc: 0.9987
# test Loss: 0.1679 Acc: 0.9264
#
# Epoch 11/25
# ----------
# train Loss: 0.0174 Acc: 0.9978
# test Loss: 0.1787 Acc: 0.9246
#
# Epoch 12/25
# ----------
# train Loss: 0.0216 Acc: 0.9969
# test Loss: 0.1566 Acc: 0.9300
#
# Epoch 13/25
# ----------
# train Loss: 0.0260 Acc: 0.9946
# test Loss: 0.1483 Acc: 0.9336
#
# Epoch 14/25
# ----------
# train Loss: 0.0173 Acc: 0.9973
# test Loss: 0.1594 Acc: 0.9246
#
# Epoch 15/25
# ----------
# train Loss: 0.0241 Acc: 0.9960
# test Loss: 0.1864 Acc: 0.9192
#
# Epoch 16/25
# ----------
# train Loss: 0.0197 Acc: 0.9973
# test Loss: 0.1668 Acc: 0.9048
#
# Epoch 17/25
# ----------
# train Loss: 0.0243 Acc: 0.9933
# test Loss: 0.1666 Acc: 0.9282
#
# Epoch 18/25
# ----------
# train Loss: 0.0222 Acc: 0.9951
# test Loss: 0.1496 Acc: 0.9425
#
# Epoch 19/25
# ----------
# train Loss: 0.0207 Acc: 0.9964
# test Loss: 0.2038 Acc: 0.9102
#
# Epoch 20/25
# ----------
# train Loss: 0.0188 Acc: 0.9960
# test Loss: 0.1978 Acc: 0.9084
#
# Epoch 21/25
# ----------
# train Loss: 0.0180 Acc: 0.9973
# test Loss: 0.1459 Acc: 0.9479
#
# Epoch 22/25
# ----------
# train Loss: 0.0269 Acc: 0.9928
# test Loss: 0.1945 Acc: 0.9120
#
# Epoch 23/25
# ----------
# train Loss: 0.0171 Acc: 0.9982
# test Loss: 0.1756 Acc: 0.9282
#
# Epoch 24/25
# ----------
# train Loss: 0.0249 Acc: 0.9942
# test Loss: 0.1664 Acc: 0.9515
#
# Epoch 25/25
# ----------
# train Loss: 0.0178 Acc: 0.9982
# test Loss: 0.1900 Acc: 0.9102
#
# Training complete in 38m 60s
# Best val Acc: 0.951526
# ---- Fold 2/5 ----
# Epoch 1/25
# ----------
# train Loss: 0.1965 Acc: 0.9339
# test Loss: 0.3076 Acc: 0.8849
#
# Epoch 2/25
# ----------
# train Loss: 0.2081 Acc: 0.9258
# test Loss: 0.2820 Acc: 0.8777
#
# Epoch 3/25
# ----------
# train Loss: 0.1789 Acc: 0.9330
# test Loss: 0.2483 Acc: 0.9011
#
# Epoch 4/25
# ----------
# train Loss: 0.2456 Acc: 0.9097
# test Loss: 0.3101 Acc: 0.8885
#
# Epoch 5/25
# ----------
# train Loss: 0.2412 Acc: 0.9204
# test Loss: 0.2743 Acc: 0.8939
#
# Epoch 6/25
# ----------
# train Loss: 0.1965 Acc: 0.9290
# test Loss: 0.2897 Acc: 0.8903
#
# Epoch 7/25
# ----------
# train Loss: 0.2003 Acc: 0.9272
# test Loss: 0.2065 Acc: 0.9155
#
# Epoch 8/25
# ----------
# train Loss: 0.1958 Acc: 0.9254
# test Loss: 0.2106 Acc: 0.9227
#
# Epoch 9/25
# ----------
# train Loss: 0.2412 Acc: 0.9249
# test Loss: 0.2178 Acc: 0.9047
#
# Epoch 10/25
# ----------
# train Loss: 0.2149 Acc: 0.9222
# test Loss: 0.1787 Acc: 0.9371
#
# Epoch 11/25
# ----------
# train Loss: 0.2625 Acc: 0.9169
# test Loss: 0.3232 Acc: 0.8687
#
# Epoch 12/25
# ----------
# train Loss: 0.1867 Acc: 0.9366
# test Loss: 0.2236 Acc: 0.9047
#
# Epoch 13/25
# ----------
# train Loss: 0.2373 Acc: 0.9164
# test Loss: 0.2282 Acc: 0.9173
#
# Epoch 14/25
# ----------
# train Loss: 0.2268 Acc: 0.9303
# test Loss: 0.2312 Acc: 0.9065
#
# Epoch 15/25
# ----------
# train Loss: 0.1977 Acc: 0.9321
# test Loss: 0.2691 Acc: 0.9137
#
# Epoch 16/25
# ----------
# train Loss: 0.2044 Acc: 0.9249
# test Loss: 0.2676 Acc: 0.9047
#
# Epoch 17/25
# ----------
# train Loss: 0.2123 Acc: 0.9285
# test Loss: 0.2302 Acc: 0.9119
#
# Epoch 18/25
# ----------
# train Loss: 0.1813 Acc: 0.9303
# test Loss: 0.2187 Acc: 0.9191
#
# Epoch 19/25
# ----------
# train Loss: 0.2062 Acc: 0.9263
# test Loss: 0.2112 Acc: 0.9065
#
# Epoch 20/25
# ----------
# train Loss: 0.1995 Acc: 0.9258
# test Loss: 0.2282 Acc: 0.9209
#
# Epoch 21/25
# ----------
# train Loss: 0.2273 Acc: 0.9231
# test Loss: 0.2995 Acc: 0.8993
#
# Epoch 22/25
# ----------
# train Loss: 0.2068 Acc: 0.9249
# test Loss: 0.2795 Acc: 0.8903
#
# Epoch 23/25
# ----------
# train Loss: 0.2082 Acc: 0.9267
# test Loss: 0.2251 Acc: 0.9083
#
# Epoch 24/25
# ----------
# train Loss: 0.2172 Acc: 0.9227
# test Loss: 0.2437 Acc: 0.9011
#
# Epoch 25/25
# ----------
# train Loss: 0.2233 Acc: 0.9245
# test Loss: 0.2407 Acc: 0.8831
#
# Training complete in 41m 6s
# Best val Acc: 0.937050
# ---- Fold 3/5 ----
# Epoch 1/25
# ----------
# train Loss: 0.2319 Acc: 0.9231
# test Loss: 0.1692 Acc: 0.9227
#
# Epoch 2/25
# ----------
# train Loss: 0.2497 Acc: 0.9173
# test Loss: 0.1574 Acc: 0.9209
#
# Epoch 3/25
# ----------
# train Loss: 0.2345 Acc: 0.9204
# test Loss: 0.1360 Acc: 0.9478
#
# Epoch 4/25
# ----------
# train Loss: 0.2075 Acc: 0.9249
# test Loss: 0.1619 Acc: 0.9317
#
# Epoch 5/25
# ----------
# train Loss: 0.2257 Acc: 0.9196
# test Loss: 0.1588 Acc: 0.9191
#
# Epoch 6/25
# ----------
# train Loss: 0.2210 Acc: 0.9222
# test Loss: 0.1249 Acc: 0.9371
#
# Epoch 7/25
# ----------
# train Loss: 0.2067 Acc: 0.9285
# test Loss: 0.1383 Acc: 0.9173
#
# Epoch 8/25
# ----------
# train Loss: 0.2502 Acc: 0.9213
# test Loss: 0.1270 Acc: 0.9460
#
# Epoch 9/25
# ----------
# train Loss: 0.2312 Acc: 0.9258
# test Loss: 0.1257 Acc: 0.9406
#
# Epoch 10/25
# ----------
# train Loss: 0.2582 Acc: 0.9124
# test Loss: 0.1230 Acc: 0.9424
#
# Epoch 11/25
# ----------
# train Loss: 0.2609 Acc: 0.9160
# test Loss: 0.1159 Acc: 0.9424
#
# Epoch 12/25
# ----------
# train Loss: 0.2492 Acc: 0.9200
# test Loss: 0.1652 Acc: 0.9388
#
# Epoch 13/25
# ----------
# train Loss: 0.2508 Acc: 0.9222
# test Loss: 0.1672 Acc: 0.9299
#
# Epoch 14/25
# ----------
# train Loss: 0.2437 Acc: 0.9191
# test Loss: 0.1426 Acc: 0.9460
#
# Epoch 15/25
# ----------
# train Loss: 0.2355 Acc: 0.9285
# test Loss: 0.1667 Acc: 0.9227
#
# Epoch 16/25
# ----------
# train Loss: 0.2737 Acc: 0.9074
# test Loss: 0.1443 Acc: 0.9335
#
# Epoch 17/25
# ----------
# train Loss: 0.2214 Acc: 0.9227
# test Loss: 0.1411 Acc: 0.9335
#
# Epoch 18/25
# ----------
# train Loss: 0.2558 Acc: 0.9128
# test Loss: 0.1438 Acc: 0.9335
#
# Epoch 19/25
# ----------
# train Loss: 0.2373 Acc: 0.9178
# test Loss: 0.1159 Acc: 0.9388
#
# Epoch 20/25
# ----------
# train Loss: 0.2193 Acc: 0.9290
# test Loss: 0.1702 Acc: 0.9245
#
# Epoch 21/25
# ----------
# train Loss: 0.2331 Acc: 0.9222
# test Loss: 0.1685 Acc: 0.9317
#
# Epoch 22/25
# ----------
# train Loss: 0.2155 Acc: 0.9272
# test Loss: 0.1654 Acc: 0.9209
#
# Epoch 23/25
# ----------
# train Loss: 0.2222 Acc: 0.9142
# test Loss: 0.1087 Acc: 0.9478
#
# Epoch 24/25
# ----------
# train Loss: 0.2200 Acc: 0.9231
# test Loss: 0.1152 Acc: 0.9496
#
# Epoch 25/25
# ----------
# train Loss: 0.2380 Acc: 0.9160
# test Loss: 0.1674 Acc: 0.9227
#
# Training complete in 39m 27s
# Best val Acc: 0.949640
# ---- Fold 4/5 ----
# Epoch 1/25
# ----------
# train Loss: 0.2458 Acc: 0.9187
# test Loss: 0.2325 Acc: 0.9173
#
# Epoch 2/25
# ----------
# train Loss: 0.1974 Acc: 0.9357
# test Loss: 0.1856 Acc: 0.9281
#
# Epoch 3/25
# ----------
# train Loss: 0.2223 Acc: 0.9231
# test Loss: 0.2246 Acc: 0.9209
#
# Epoch 4/25
# ----------
# train Loss: 0.2032 Acc: 0.9276
# test Loss: 0.1132 Acc: 0.9622
#
# Epoch 5/25
# ----------
# train Loss: 0.1856 Acc: 0.9344
# test Loss: 0.1366 Acc: 0.9478
#
# Epoch 6/25
# ----------
# train Loss: 0.2599 Acc: 0.9231
# test Loss: 0.1952 Acc: 0.9353
#
# Epoch 7/25
# ----------
# train Loss: 0.2145 Acc: 0.9285
# test Loss: 0.1396 Acc: 0.9371
#
# Epoch 8/25
# ----------
# train Loss: 0.2035 Acc: 0.9321
# test Loss: 0.2182 Acc: 0.9227
#
# Epoch 9/25
# ----------
# train Loss: 0.2368 Acc: 0.9240
# test Loss: 0.1701 Acc: 0.9406
#
# Epoch 10/25
# ----------
# train Loss: 0.2237 Acc: 0.9299
# test Loss: 0.2177 Acc: 0.9101
#
# Epoch 11/25
# ----------
# train Loss: 0.2451 Acc: 0.9204
# test Loss: 0.1906 Acc: 0.9388
#
# Epoch 12/25
# ----------
# train Loss: 0.2555 Acc: 0.9106
# test Loss: 0.1905 Acc: 0.9335
#
# Epoch 13/25
# ----------
# train Loss: 0.1895 Acc: 0.9317
# test Loss: 0.1972 Acc: 0.9317
#
# Epoch 14/25
# ----------
# train Loss: 0.2335 Acc: 0.9249
# test Loss: 0.1747 Acc: 0.9281
#
# Epoch 15/25
# ----------
# train Loss: 0.2319 Acc: 0.9209
# test Loss: 0.1482 Acc: 0.9640
#
# Epoch 16/25
# ----------
# train Loss: 0.2618 Acc: 0.9204
# test Loss: 0.2058 Acc: 0.9119
#
# Epoch 17/25
# ----------
# train Loss: 0.2210 Acc: 0.9240
# test Loss: 0.1637 Acc: 0.9388
#
# Epoch 18/25
# ----------
# train Loss: 0.2295 Acc: 0.9249
# test Loss: 0.1678 Acc: 0.9406
#
# Epoch 19/25
# ----------
# train Loss: 0.2202 Acc: 0.9236
# test Loss: 0.1825 Acc: 0.9371
#
# Epoch 20/25
# ----------
# train Loss: 0.2291 Acc: 0.9196
# test Loss: 0.1650 Acc: 0.9281
#
# Epoch 21/25
# ----------
# train Loss: 0.2292 Acc: 0.9240
# test Loss: 0.1763 Acc: 0.9478
#
# Epoch 22/25
# ----------
# train Loss: 0.2344 Acc: 0.9204
# test Loss: 0.1194 Acc: 0.9532
#
# Epoch 23/25
# ----------
# train Loss: 0.1978 Acc: 0.9294
# test Loss: 0.1240 Acc: 0.9514
#
# Epoch 24/25
# ----------
# train Loss: 0.2514 Acc: 0.9263
# test Loss: 0.1945 Acc: 0.9353
#
# Epoch 25/25
# ----------
# train Loss: 0.2064 Acc: 0.9308
# test Loss: 0.2031 Acc: 0.9281
#
# Training complete in 39m 28s
# Best val Acc: 0.964029
# ---- Fold 5/5 ----
# Epoch 1/25
# ----------
# train Loss: 0.2562 Acc: 0.9236
# test Loss: 0.0947 Acc: 0.9676
#
# Epoch 2/25
# ----------
# train Loss: 0.2165 Acc: 0.9276
# test Loss: 0.1413 Acc: 0.9496
#
# Epoch 3/25
# ----------
# train Loss: 0.2193 Acc: 0.9290
# test Loss: 0.1338 Acc: 0.9460
#
# Epoch 4/25
# ----------
# train Loss: 0.2287 Acc: 0.9196
# test Loss: 0.1293 Acc: 0.9496
#
# Epoch 5/25
# ----------
# train Loss: 0.2627 Acc: 0.9133
# test Loss: 0.1137 Acc: 0.9568
#
# Epoch 6/25
# ----------
# train Loss: 0.2094 Acc: 0.9267
# test Loss: 0.1382 Acc: 0.9532
#
# Epoch 7/25
# ----------
# train Loss: 0.2296 Acc: 0.9272
# test Loss: 0.1652 Acc: 0.9478
#
# Epoch 8/25
# ----------
# train Loss: 0.2290 Acc: 0.9227
# test Loss: 0.1365 Acc: 0.9514
#
# Epoch 9/25
# ----------
# train Loss: 0.2447 Acc: 0.9137
# test Loss: 0.1348 Acc: 0.9424
#
# Epoch 10/25
# ----------
# train Loss: 0.2031 Acc: 0.9312
# test Loss: 0.2536 Acc: 0.9119
#
# Epoch 11/25
# ----------
# train Loss: 0.2656 Acc: 0.9200
# test Loss: 0.1888 Acc: 0.9478
#
# Epoch 12/25
# ----------
# train Loss: 0.2086 Acc: 0.9276
# test Loss: 0.1447 Acc: 0.9640
#
# Epoch 13/25
# ----------
# train Loss: 0.2066 Acc: 0.9276
# test Loss: 0.1674 Acc: 0.9442
#
# Epoch 14/25
# ----------
# train Loss: 0.2091 Acc: 0.9290
# test Loss: 0.1154 Acc: 0.9514
#
# Epoch 15/25
# ----------
# train Loss: 0.2870 Acc: 0.9110
# test Loss: 0.1737 Acc: 0.9335
#
# Epoch 16/25
# ----------
# train Loss: 0.2153 Acc: 0.9245
# test Loss: 0.1334 Acc: 0.9568
#
# Epoch 17/25
# ----------
# train Loss: 0.2084 Acc: 0.9240
# test Loss: 0.1134 Acc: 0.9712
#
# Epoch 18/25
# ----------
# train Loss: 0.1634 Acc: 0.9420
# test Loss: 0.1086 Acc: 0.9568
#
# Epoch 19/25
# ----------
# train Loss: 0.1997 Acc: 0.9366
# test Loss: 0.1578 Acc: 0.9496
#
# Epoch 20/25
# ----------
# train Loss: 0.2355 Acc: 0.9196
# test Loss: 0.1295 Acc: 0.9550
#
# Epoch 21/25
# ----------
# train Loss: 0.2291 Acc: 0.9169
# test Loss: 0.1468 Acc: 0.9532
#
# Epoch 22/25
# ----------
# train Loss: 0.2469 Acc: 0.9218
# test Loss: 0.1481 Acc: 0.9388
#
# Epoch 23/25
# ----------
# train Loss: 0.2221 Acc: 0.9196
# test Loss: 0.1457 Acc: 0.9514
#
# Epoch 24/25
# ----------
# train Loss: 0.1936 Acc: 0.9308
# test Loss: 0.1498 Acc: 0.9532
#
# Epoch 25/25
# ----------
# train Loss: 0.2119 Acc: 0.9227
# test Loss: 0.1054 Acc: 0.9586
#
# Training complete in 39m 6s
# Best val Acc: 0.971223
# Best val Acc after k-folds: 0.971223

# %%
torch.save(model_fit, './models/resnet18_pretrained.pth')

# %%
model = torch.load('./models/resnet18_pretrained.pth')

# %%
model = torch.load('./models/resnet_18.pth')

# %%
test_model(data_loader.test_loader, model)
# Out:
# cctv simple accuracy is: 0.943
# cctv precision is: 0.9088
# cctv recall is: 0.9789
# cctv f1 is: 0.9426
# other simple accuracy is: 0.943
# other precision is: 0.9793
# other recall is: 0.9103
# other f1 is: 0.9435
